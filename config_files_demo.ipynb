# %% [markdown]
# <a href="https://colab.research.google.com/github/nitrogenlab/GP15_watermassanalysis/blob/main/config_files_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyompa
# Out:
# Collecting pyompa
#   Downloading https://files.pythonhosted.org/packages/9e/c7/4fd52aa23b7a6e3732160535dff7f823f8ebfb7e89b2dea6273d7ea3f549/pyompa-0.3.0.2.tar.gz
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from pyompa) (1.19.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from pyompa) (1.1.5)
# Requirement already satisfied: cvxpy in /usr/local/lib/python3.6/dist-packages (from pyompa) (1.0.31)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from pyompa) (1.4.1)
# Requirement already satisfied: toml in /usr/local/lib/python3.6/dist-packages (from pyompa) (0.10.2)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas->pyompa) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas->pyompa) (2.8.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.6/dist-packages (from cvxpy->pyompa) (0.70.11.1)
# Requirement already satisfied: osqp>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from cvxpy->pyompa) (0.6.2)
# Requirement already satisfied: scs>=1.1.3 in /usr/local/lib/python3.6/dist-packages (from cvxpy->pyompa) (2.1.2)
# Requirement already satisfied: ecos>=2 in /usr/local/lib/python3.6/dist-packages (from cvxpy->pyompa) (2.0.7.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.7.3->pandas->pyompa) (1.15.0)
# Requirement already satisfied: dill>=0.3.3 in /usr/local/lib/python3.6/dist-packages (from multiprocess->cvxpy->pyompa) (0.3.3)
# Requirement already satisfied: qdldl in /usr/local/lib/python3.6/dist-packages (from osqp>=0.4.1->cvxpy->pyompa) (0.1.5.post0)
# Building wheels for collected packages: pyompa
#   Building wheel for pyompa (setup.py) ... done
#   Created wheel for pyompa: filename=pyompa-0.3.0.2-cp36-none-any.whl size=17693 sha256=8008bf88e26b879d58300481c922248d43aae5389f4ea8dfb8a08628d2195def
#   Stored in directory: /root/.cache/pip/wheels/5e/e1/7c/e88aca6c0a7d5433e2a5573c77d9201bd8255c0871292d8595
# Successfully built pyompa
# Installing collected packages: pyompa
# Successfully installed pyompa-0.3.0.2

# %%
# !wget https://github.com/nitrogenlab/GP15_watermassanalysis/raw/main/endmember_df_intermediateanddeep.csv
# !wget https://github.com/nitrogenlab/GP15_watermassanalysis/raw/main/gp15_intermediateanddeep_obs.csv
# !wget https://github.com/nitrogenlab/GP15_watermassanalysis/raw/main/config_examples/config_example1.txt -O config_file.txt
# Out:
# --2021-01-15 20:42:03--  https://github.com/nitrogenlab/GP15_watermassanalysis/raw/main/endmember_df_intermediateanddeep.csv
# Resolving github.com (github.com)... 140.82.121.4
# Connecting to github.com (github.com)|140.82.121.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/nitrogenlab/GP15_watermassanalysis/main/endmember_df_intermediateanddeep.csv [following]
# --2021-01-15 20:42:03--  https://raw.githubusercontent.com/nitrogenlab/GP15_watermassanalysis/main/endmember_df_intermediateanddeep.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 772 [text/plain]
# Saving to: ‘endmember_df_intermediateanddeep.csv’
#
# endmember_df_interm 100%[===================>]     772  --.-KB/s    in 0s
#
# 2021-01-15 20:42:03 (41.8 MB/s) - ‘endmember_df_intermediateanddeep.csv’ saved [772/772]
#
# --2021-01-15 20:42:04--  https://github.com/nitrogenlab/GP15_watermassanalysis/raw/main/gp15_intermediateanddeep_obs.csv
# Resolving github.com (github.com)... 140.82.121.4
# Connecting to github.com (github.com)|140.82.121.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/nitrogenlab/GP15_watermassanalysis/main/gp15_intermediateanddeep_obs.csv [following]
# --2021-01-15 20:42:04--  https://raw.githubusercontent.com/nitrogenlab/GP15_watermassanalysis/main/gp15_intermediateanddeep_obs.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 151333 (148K) [text/plain]
# Saving to: ‘gp15_intermediateanddeep_obs.csv’
#
# gp15_intermediatean 100%[===================>] 147.79K  --.-KB/s    in 0.01s
#
# 2021-01-15 20:42:04 (12.7 MB/s) - ‘gp15_intermediateanddeep_obs.csv’ saved [151333/151333]
#
# --2021-01-15 20:42:04--  https://github.com/nitrogenlab/GP15_watermassanalysis/raw/main/config_examples/config_example1.txt
# Resolving github.com (github.com)... 140.82.121.4
# Connecting to github.com (github.com)|140.82.121.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/nitrogenlab/GP15_watermassanalysis/main/config_examples/config_example1.txt [following]
# --2021-01-15 20:42:04--  https://raw.githubusercontent.com/nitrogenlab/GP15_watermassanalysis/main/config_examples/config_example1.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1280 (1.2K) [text/plain]
# Saving to: ‘config_file.txt’
#
# config_file.txt     100%[===================>]   1.25K  --.-KB/s    in 0s
#
# 2021-01-15 20:42:05 (88.1 MB/s) - ‘config_file.txt’ saved [1280/1280]

# %%
from pyompa.parse_config import run_ompa_given_toml_config_file
from pyompa import (plot_ompasoln_endmember_fractions,
                    plot_ompasoln_residuals,
                    plot_ompaproblem_endmember_usagepenalties,
                    build_altair_viz)

ompa_soln = run_ompa_given_toml_config_file("config_file.txt")
# Out:
# Received Config:
# {
#     "observations": {
#         "csv_file": "gp15_intermediateanddeep_obs.csv",
#         "na_values": -999
#     },
#     "params": {
#         "potential_temp": {
#             "weight": 56.0,
#             "remineralized": false
#         },
#         "practical_salinity": {
#             "weight": 80.0,
#             "remineralized": false
#         },
#         "silicate": {
#             "weight": 3.0,
#             "remineralized": false
#         },
#         "nitrate": {
#             "weight": 5.0,
#             "remineralized": true,
#             "ratios": [
#                 0.10330578512,
#                 0.10330578512
#             ]
#         },
#         "phosphate": {
#             "weight": 5.0,
#             "remineralized": true,
#             "ratios": [
#                 0.01036168132,
#                 0.00327210989
#             ]
#         },
#         "oxygen": {
#             "weight": 1.0,
#             "remineralized": true,
#             "ratios": [
#                 -1,
#                 -1
#             ]
#         }
#     },
#     "endmembers": {
#         "csv_file": "endmember_df_intermediateanddeep.csv",
#         "endmember_name_column": "endmember_name"
#     },
#     "endmember_penalties": {
#         "PSUW": {
#             "lat": {
#                 "type": "latlon_default",
#                 "lowerbound": 10
#             }
#         },
#         "LCDW": {
#             "sigma0": {
#                 "type": "density_default",
#                 "lowerbound": 27.72
#             }
#         },
#         "AABW": {
#             "sigma0": {
#                 "type": "density_default",
#                 "lowerbound": 27.72
#             }
#         }
#     },
#     "export": {
#         "csv_output_name": "ompa_soln.csv",
#         "orig_cols_to_include": [
#             "lat",
#             "lon",
#             "depth",
#             "stnnbr",
#             "geotrc_ID"
#         ],
#         "export_orig_param_vals": false,
#         "export_residuals": true,
#         "export_endmember_fracs": true,
#         "export_oxygen_deficit": true,
#         "export_conversion_ratios": true,
#         "export_endmember_usage_penalties": true
#     }
# }
# Adding penalty for PSUW
# Adding penalty for LCDW
# Adding penalty for AABW
# params to use: ['potential_temp', 'practical_salinity', 'silicate'] ['nitrate', 'phosphate', 'oxygen']
# param weighting: [56. 80.  3.  5.  5.  1.]
# Conversion ratios:
# [[ 0.10330579  0.01036168 -1.        ]
#  [ 0.10330579  0.00327211 -1.        ]]
# status: optimal
# optimal value 25365.437007426797
# Original weighted sum squares: 25346.82610980811
# Post fix weighted sum squared: 25347.103418187646
# status: optimal
# optimal value 872433.3403418912
# Original weighted sum squares: 872415.8837117155
# Post fix weighted sum squared: 872415.8841835157
# status: optimal
# optimal value 22521.367526545866
# Original weighted sum squares: 22501.359836396867
# Post fix weighted sum squared: 22501.48682822343
# objective: 22501.48682822343
# writing to ompa_soln.csv

# %%
plot_ompasoln_endmember_fractions(ompa_soln, xaxis_colname="lat",
                                  yaxis_colname="depth")
plot_ompasoln_residuals(ompa_soln, xaxis_colname="lat", yaxis_colname="depth")

# %%
build_altair_viz(ompa_soln, xaxis_colname="lat", yaxis_colname="depth" )
# Out:
# alt.VConcatChart(...)
