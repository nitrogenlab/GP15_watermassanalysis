# %% [markdown]
# <a href="https://colab.research.google.com/github/nitrogenlab/GP15_watermassanalysis/blob/master/ThermoclineSplittingDevHighres.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gsw
import gsw
# Out:
# Requirement already satisfied: gsw in /usr/local/lib/python3.6/dist-packages (3.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from gsw) (1.19.5)

# %%
# !wget https://cchdo.ucsd.edu/data/16482/33RR20180918_ct1.zip -O 33RR20180918_ct1.zip
# Out:
# --2021-02-08 18:58:46--  https://cchdo.ucsd.edu/data/16482/33RR20180918_ct1.zip
# Resolving cchdo.ucsd.edu (cchdo.ucsd.edu)... 44.241.13.136
# Connecting to cchdo.ucsd.edu (cchdo.ucsd.edu)|44.241.13.136|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3224609 (3.1M) [application/zip]
# Saving to: ‘33RR20180918_ct1.zip’
#
# 33RR20180918_ct1.zi  83%[===============>    ]   2.57M   736KB/s    eta 1s     ^C

# %%
# !unzip 33RR20180918_ct1.zip
# Out:
# Archive:  33RR20180918_ct1.zip
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of 33RR20180918_ct1.zip or
#         33RR20180918_ct1.zip.zip, and cannot find 33RR20180918_ct1.zip.ZIP, period.

# %%
import pandas as pd
from io import StringIO
from collections import namedtuple
import glob


def parse_ctd_dataset(filename):
  num_headers = None
  headers_passed = 0
  table_line_number = 0
  latitude = None
  longitude = None
  core_file_contents = ""
  with open(filename) as fh:
    for line in fh:
      line = line.rstrip("\n")
      if line.startswith("NUMBER_HEADERS"):
        num_headers = int(line.split(" = ")[1])
        headers_passed += 1
      elif num_headers is None:
        continue #haven't seen the num_headers line yeat
      else:
        if (headers_passed < num_headers):
          headers_passed += 1
          if (line.startswith("LATITUDE")):
            latitude = float(line.split(" = ")[1])
          if (line.startswith("LONGITUDE")):
            longitude = float(line.split(" = ")[1])
        else:
          #actually parsing the table
          table_line_number += 1
          if (table_line_number==1):
            core_file_contents += line+",LATITUDE,LONGITUDE\n" #header
          elif table_line_number==2:
            continue #this is a line with the units
          else:
            if (line.startswith("END_DATA")==False):
              core_file_contents +=\
                line+","+str(latitude)+","+str(longitude)+"\n"
            else:
              return pd.read_csv(StringIO(core_file_contents)), latitude, longitude


def get_density_depth_info(df, salinity_col="CTDSAL",
                                  temp_col="CTDTMP",
                                  pressure_col="CTDPRS",
                                  latitude_col="LATITUDE",
                                  longitude_col="LONGITUDE"):
  absolute_salinity = gsw.SA_from_SP(SP=df[salinity_col],
                                     p=df[pressure_col],
                                     lon=df[longitude_col],
                                     lat=df[latitude_col])
  conservative_temp = gsw.CT_from_t(SA=absolute_salinity,
                                    t=df["CTDTMP"], p=df["CTDPRS"])
  sig0 = gsw.rho(SA=absolute_salinity, CT=conservative_temp, p=0) - 1000

  z = gsw.z_from_p(p=df[pressure_col], lat=df[latitude_col])
  depth = -z #https://github.com/TEOS-10/python-gsw/blob/7d6ebe8114c5d8b4a64268d36100a70e226afaf6/gsw/gibbs/conversions.py#L577
  return sig0, depth


StnData = namedtuple("StnData", ["df", "pressure", "sig0", "depth",
                                 "lat", "lon", "cast"])


def parse_all_station_cast_info(files):
  stn_to_data = {}
  for file in files:
    _, stnstr, stncast, _ = file.split("_")
    stn = int(stnstr)
    cast = int(stncast)
    print("On station",stn,"cast",cast)
    ctd_df, lat, lon = parse_ctd_dataset(file)
    sig0, depth = get_density_depth_info(df=ctd_df)
    stn_data = StnData(df=ctd_df, pressure=ctd_df["CTDPRS"],
                       sig0=sig0, depth=depth, lat=lat, lon=lon, cast=cast)
    if (stn not in stn_to_data):
      stn_to_data[stn] = stn_data
    else:
      if (len(sig0) > len(stn_to_data[stn].sig0)): 
        print("Replacing cast",stn_to_data[stn].cast,
              "and length",len(stn_to_data[stn].sig0),
              "with cast",cast,"and length",len(sig0))
  return stn_to_data

stn_to_data = parse_all_station_cast_info(glob.glob("*.csv"))
#parse_ctd_dataset("33RR20180918_00001_00002_ct1.csv")
# Out:
# On station 27 cast 5
# On station 39 cast 10
# On station 13 cast 3
# On station 6 cast 9
# On station 34 cast 2
# On station 21 cast 6
# On station 31 cast 3
# On station 186 cast 3
# On station 16 cast 5
# On station 35 cast 6
# On station 5 cast 6
# On station 13 cast 2
# Replacing cast 3 and length 505 with cast 2 and length 531
# On station 35 cast 13
# Replacing cast 6 and length 2601 with cast 13 and length 2605
# On station 33 cast 2
# On station 5 cast 5
# On station 34 cast 3
# On station 6 cast 6
# On station 5 cast 9
# Replacing cast 6 and length 2336 with cast 9 and length 2342
# On station 8 cast 3
# On station 7 cast 3
# On station 35 cast 3
# On station 14 cast 9
# On station 25 cast 3
# On station 10 cast 3
# On station 15 cast 3
# On station 31 cast 5
# Replacing cast 3 and length 202 with cast 5 and length 707
# On station 11 cast 2
# On station 37 cast 2
# On station 9 cast 2
# On station 31 cast 6
# Replacing cast 3 and length 202 with cast 6 and length 2343
# On station 39 cast 2
# On station 33 cast 8
# Replacing cast 2 and length 757 with cast 8 and length 910
# On station 35 cast 10
# On station 27 cast 6
# Replacing cast 5 and length 708 with cast 6 and length 2312
# On station 12 cast 10
# On station 39 cast 5
# On station 27 cast 2
# Replacing cast 5 and length 708 with cast 2 and length 1010
# On station 10 cast 2
# Replacing cast 3 and length 507 with cast 2 and length 532
# On station 20 cast 2
# On station 16 cast 2
# Replacing cast 5 and length 430 with cast 2 and length 555
# On station 7 cast 2
# Replacing cast 3 and length 507 with cast 2 and length 518
# On station 35 cast 5
# On station 5 cast 2
# On station 17 cast 3
# On station 10 cast 6
# Replacing cast 3 and length 507 with cast 6 and length 2589
# On station 6 cast 3
# On station 18 cast 9
# On station 17 cast 2
# Replacing cast 3 and length 505 with cast 2 and length 530
# On station 19 cast 11
# On station 14 cast 12
# Replacing cast 9 and length 962 with cast 12 and length 1292
# On station 12 cast 4
# On station 23 cast 10
# On station 19 cast 7
# On station 19 cast 2
# On station 8 cast 13
# Replacing cast 3 and length 203 with cast 13 and length 2614
# On station 16 cast 9
# Replacing cast 5 and length 430 with cast 9 and length 2731
# On station 6 cast 5
# On station 10 cast 9
# Replacing cast 3 and length 507 with cast 9 and length 2590
# On station 22 cast 3
# On station 12 cast 2
# Replacing cast 10 and length 1088 with cast 2 and length 1269
# On station 29 cast 3
# On station 29 cast 5
# On station 183 cast 2
# On station 14 cast 5
# On station 1 cast 2
# On station 18 cast 3
# On station 20 cast 3
# On station 38 cast 2
# On station 21 cast 11
# Replacing cast 6 and length 2729 with cast 11 and length 2734
# On station 25 cast 9
# Replacing cast 3 and length 227 with cast 9 and length 1036
# On station 2 cast 3
# On station 31 cast 9
# Replacing cast 3 and length 202 with cast 9 and length 935
# On station 4 cast 8
# On station 23 cast 9
# On station 4 cast 3
# On station 37 cast 8
# Replacing cast 2 and length 755 with cast 8 and length 910
# On station 8 cast 10
# Replacing cast 3 and length 203 with cast 10 and length 1295
# On station 4 cast 9
# Replacing cast 8 and length 1272 with cast 9 and length 2851
# On station 25 cast 2
# Replacing cast 3 and length 227 with cast 2 and length 675
# On station 23 cast 5
# Replacing cast 10 and length 1698 with cast 5 and length 2642
# On station 12 cast 6
# On station 29 cast 6
# Replacing cast 3 and length 177 with cast 6 and length 2211
# On station 18 cast 6
# On station 12 cast 12
# Replacing cast 10 and length 1088 with cast 12 and length 2846
# On station 33 cast 11
# Replacing cast 2 and length 757 with cast 11 and length 2704
# On station 18 cast 2
# On station 5 cast 3
# On station 9 cast 3
# On station 21 cast 8
# On station 35 cast 2
# On station 8 cast 6
# Replacing cast 3 and length 203 with cast 6 and length 2608
# On station 37 cast 11
# Replacing cast 2 and length 755 with cast 11 and length 2426
# On station 19 cast 5
# On station 19 cast 8
# On station 14 cast 13
# Replacing cast 9 and length 962 with cast 13 and length 2670
# On station 19 cast 4
# On station 29 cast 2
# Replacing cast 3 and length 177 with cast 2 and length 503
# On station 8 cast 5
# Replacing cast 3 and length 203 with cast 5 and length 204
# On station 27 cast 9
# Replacing cast 5 and length 708 with cast 9 and length 935
# On station 23 cast 6
# On station 10 cast 5
# On station 4 cast 5
# On station 1 cast 3
# On station 36 cast 2
# On station 27 cast 3
# On station 8 cast 12
# Replacing cast 3 and length 203 with cast 12 and length 988
# On station 33 cast 9
# Replacing cast 2 and length 757 with cast 9 and length 937
# On station 21 cast 5
# On station 29 cast 10
# Replacing cast 3 and length 177 with cast 10 and length 1140
# On station 23 cast 2
# On station 39 cast 9
# On station 14 cast 3
# On station 29 cast 12
# Replacing cast 3 and length 177 with cast 12 and length 504
# On station 18 cast 5
# On station 16 cast 6
# Replacing cast 5 and length 430 with cast 6 and length 2719
# On station 4 cast 2
# On station 27 cast 11
# Replacing cast 5 and length 708 with cast 11 and length 2313
# On station 29 cast 13
# Replacing cast 3 and length 177 with cast 13 and length 2213
# On station 38 cast 3
# On station 16 cast 3
# On station 12 cast 9
# On station 39 cast 6
# Replacing cast 10 and length 833 with cast 6 and length 2134
# On station 25 cast 6
# Replacing cast 3 and length 227 with cast 6 and length 2550
# On station 31 cast 2
# Replacing cast 3 and length 202 with cast 2 and length 757
# On station 25 cast 8
# Replacing cast 3 and length 227 with cast 8 and length 1012
# On station 33 cast 6
# Replacing cast 2 and length 757 with cast 6 and length 2706
# On station 19 cast 12
# On station 12 cast 7
# Replacing cast 10 and length 1088 with cast 7 and length 2834
# On station 37 cast 6
# Replacing cast 2 and length 755 with cast 6 and length 2425
# On station 27 cast 8
# Replacing cast 5 and length 708 with cast 8 and length 910
# On station 3 cast 6
# On station 8 cast 9
# Replacing cast 3 and length 203 with cast 9 and length 964
# On station 3 cast 3
# On station 23 cast 12
# On station 36 cast 3
# On station 31 cast 11
# Replacing cast 3 and length 202 with cast 11 and length 2347
# On station 35 cast 12
# On station 6 cast 2
# On station 39 cast 3
# On station 14 cast 10
# On station 35 cast 9
# On station 31 cast 8
# Replacing cast 3 and length 202 with cast 8 and length 910
# On station 186 cast 2
# Replacing cast 3 and length 652 with cast 2 and length 655
# On station 22 cast 2
# Replacing cast 3 and length 506 with cast 2 and length 528
# On station 33 cast 3
# On station 33 cast 5
# On station 14 cast 6
# Replacing cast 9 and length 962 with cast 6 and length 2664
# On station 23 cast 4
# On station 23 cast 13
# Replacing cast 10 and length 1698 with cast 13 and length 2657
# On station 25 cast 5
# Replacing cast 3 and length 227 with cast 5 and length 1011
# On station 37 cast 3
# On station 37 cast 5
# Replacing cast 2 and length 755 with cast 5 and length 910
# On station 37 cast 9
# Replacing cast 2 and length 755 with cast 9 and length 938
# On station 183 cast 1
# Replacing cast 2 and length 1078 with cast 1 and length 1082
# On station 8 cast 2
# Replacing cast 3 and length 203 with cast 2 and length 309
# On station 3 cast 2
# On station 15 cast 2
# Replacing cast 3 and length 506 with cast 2 and length 530
# On station 4 cast 11
# Replacing cast 8 and length 1272 with cast 11 and length 2854
# On station 21 cast 2
# On station 25 cast 11
# Replacing cast 3 and length 227 with cast 11 and length 2554
# On station 3 cast 4
# On station 14 cast 2
# On station 29 cast 9
# Replacing cast 3 and length 177 with cast 9 and length 808
# On station 21 cast 3
# On station 4 cast 6
# Replacing cast 8 and length 1272 with cast 6 and length 1280
# On station 39 cast 12
# Replacing cast 10 and length 833 with cast 12 and length 2162
# On station 21 cast 9

# %%
import scipy.interpolate
import scipy.signal
import sklearn.isotonic
import numpy as np
from matplotlib import pyplot as plt

TC_UPPER_BOUND = 26.6
TC_LOWER_BOUND = 25.5

#let's plot the profiles per-station
for stn in sorted(stn_to_data.keys()):
    stn_data = stn_to_data[stn]
    #fit a spline to it
    density = np.array(stn_data.sig0)
    depth = np.array(stn_data.depth)

    argsort_depth = np.argsort(depth)
    sorted_depth = depth[argsort_depth]
    sorted_density = density[argsort_depth]
    
    #'correct' the density to enforce monotonic increase with depth
    sorted_monotonic_density = (sklearn.isotonic.IsotonicRegression()
       .fit_transform(X=sorted_depth, y=sorted_density))

    fig, ax1 = plt.subplots(figsize=(10,12))
    fig.suptitle("stnnbr: "+str(stn)
                 +" cast: "+str(stn_data.cast)
                 +" lat: "+str(stn_data.lat)
                 +" lon: "+str(stn_data.lon))
    ax1.set_ylabel("-depth")

    ax1.scatter(sorted_density, -sorted_depth, s=8, color='C0')

    ##Smooth the density with a savgol filter
    #sorted_smooth_density = scipy.signal.savgol_filter(sorted_density, 5, 2)
    #ax1.plot(sorted_smooth_density, -sorted_depth, color='C1')
    
    pchip_spl = scipy.interpolate.PchipInterpolator(
                 sorted_depth, sorted_monotonic_density)
    interp_depths = np.linspace(min(depth), max(depth), 1000)
    interp_density = pchip_spl(interp_depths)

    ax1.plot(interp_density, -interp_depths, color="C0")
    ax1.set_xlabel("Density")

    #Plot the flat density-based thresholds
    density_cutoff_tc_depths = (
        interp_depths[(interp_density <= TC_UPPER_BOUND)*
                      (interp_density >= TC_LOWER_BOUND)])
    density_cutoff_tc_start_depth = (np.min(density_cutoff_tc_depths) if
      len(density_cutoff_tc_depths) > 0 else np.nan)
    density_cutoff_tc_end_depth = (np.max(density_cutoff_tc_depths) if
      len(density_cutoff_tc_depths) > 0 else np.nan)
    ax1.plot([min(density), max(density)],
             [-density_cutoff_tc_start_depth, -density_cutoff_tc_start_depth],
             color="C0", linestyle=":")
    ax1.plot([min(density), max(density)],
             [-density_cutoff_tc_end_depth, -density_cutoff_tc_end_depth],
             color="C0", linestyle=":")
    #ax1.plot(akima_spl(interp_depths), -interp_depths)

    ax1.tick_params(axis='x', colors='C0')
    ax1.xaxis.label.set_color('C0')
    ax2 = ax1.twiny()
    ax2.tick_params(axis='x', colors='C3')
    ax2.xaxis.label.set_color('C3')

    first_derivatives = pchip_spl.derivative(1)(interp_depths)
    
    ax2.plot(first_derivatives, -interp_depths, color="C2", linestyle="--")
    
    ax2.set_xlabel("d(density)/d(depth)")
    
    #Procedure: find the maximum of the first derivative, then fit isotonic
    # regression to enforce monotonic increasing and monotic decreasing to
    # get a better estimate of the derivatives.

    max_first_d_depth = np.argmax(first_derivatives)+1
    if (max_first_d_depth > 1):
      increasing_first_d = sklearn.isotonic.IsotonicRegression().fit_transform(
            X=interp_depths[:max_first_d_depth],
            y=first_derivatives[:max_first_d_depth])
    else:
      increasing_first_d = [first_derivatives[0]]
    decreasing_first_d = -sklearn.isotonic.IsotonicRegression().fit_transform(
           X=interp_depths[max_first_d_depth:],
           y=-first_derivatives[max_first_d_depth:])

    corrected_first_d = np.array(list(increasing_first_d)
                                 +list(decreasing_first_d))
    ax2.plot(corrected_first_d, -interp_depths, color="C3")

    #threhsolds based on first_d
    THERM_SIGMA0_GRAD_START = min(0.25*np.max(corrected_first_d), 0.01)
    THERM_SIGMA0_GRAD_END = 0.003
    firstd_cutoff_tc_depths = (
        interp_depths[(corrected_first_d >= THERM_SIGMA0_GRAD_START)])
    firstd_cutoff_tc_start_depth = np.min(
        interp_depths[(corrected_first_d >= THERM_SIGMA0_GRAD_START)])
    firstd_cutoff_tc_end_depth = (np.max(
        interp_depths[(corrected_first_d >= THERM_SIGMA0_GRAD_END)]) if
      sum((corrected_first_d >= THERM_SIGMA0_GRAD_END)) > 0 else np.nan)
    ax1.plot([min(density), max(density)],
             [-firstd_cutoff_tc_start_depth, -firstd_cutoff_tc_start_depth],
             color="C3", linestyle=":")
    ax1.plot([min(density), max(density)],
             [-firstd_cutoff_tc_end_depth, -firstd_cutoff_tc_end_depth],
             color="C3", linestyle=":")
    
    plt.show()
#plt.show()

# %%
import glob
